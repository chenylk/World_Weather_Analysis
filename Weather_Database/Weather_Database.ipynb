# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy

# %%
#creating 2000 random lattitude and longitudes
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
#creating a list of the coordinates
coordinates = list(lats_lngs)

# %%
#get the nearest city using citipy module
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
print(len(cities))
# Out:
# 731

# %%
#import extra dependencies
import requests
from datetime import datetime

from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

#loop through all the cities in the list
for i, city in enumerate(cities):
    
    #create enpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #run api request for each of the cities
    try:
        #parse the json and retrieve data
        city_weather = requests.get(city_url).json()
        #parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        #convert the data to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        #append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        
        
    except:
        print("City not found. Skipping...")
        pass
print(len(city_data))
# Out:
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# 679

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head()
# Out:
#             City    Lat    Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  San Cristobal   7.77 -72.22     91.40        43          20       19.46
# 1    Krasnotorka  48.68  37.53     63.57        54          51        5.79
# 2          Adrar  20.50 -10.07    111.15         7          22       17.29
# 3        Ushuaia -54.80 -68.30     41.00        80          75        4.70
# 4       Coquimbo -29.95 -71.34     51.80        81          90        4.70
#
#   Country Current Description
# 0      VE          few clouds
# 1      UA       broken clouds
# 2      MR          few clouds
# 3      AR         shower rain
# 4      CL     overcast clouds

# %%
new_columns_df = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df = city_data_df[new_columns_df]

# %%
city_data_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  San Cristobal      VE   7.77  -72.22     91.40        43          20
# 1    Krasnotorka      UA  48.68   37.53     63.57        54          51
# 2          Adrar      MR  20.50  -10.07    111.15         7          22
# 3        Ushuaia      AR -54.80  -68.30     41.00        80          75
# 4       Coquimbo      CL -29.95  -71.34     51.80        81          90
# 5     Nikolskoye      RU  59.70   30.79     70.00        56          20
# 6   Puerto Ayora      EC  -0.74  -90.35     71.60        73          40
# 7         Castro      BR -24.79  -50.01     51.62        70          71
# 8          Sitka      US  57.05 -135.33     53.60       100          90
# 9       Goderich      CA  43.75  -81.72     82.00        80           1
#
#    Wind Speed Current Description
# 0       19.46          few clouds
# 1        5.79       broken clouds
# 2       17.29          few clouds
# 3        4.70         shower rain
# 4        4.70     overcast clouds
# 5        6.71          few clouds
# 6       12.75    scattered clouds
# 7        9.75       broken clouds
# 8        3.36                mist
# 9        5.01           clear sky

# %%
#create output file (csv)
output_data_file = 'WeatherPy_Database.csv'
#export the data into csv
city_data_df.to_csv(output_data_file)
